# %%
import numpy as np

data = np.genfromtxt('data.txt')
print(data)
# Out:
# [3.2000000e+01 6.4000000e+01 1.2800000e+02 2.5600000e+02 5.1200000e+02
#  1.0240000e+03 2.0480000e+03 4.0960000e+03 8.1920000e+03 1.6384000e+04
#  3.2768000e+04 6.5536000e+04 1.3107200e+05 2.6214400e+05 5.2428800e+05
#  1.0485760e+06 2.0971520e+06 4.1943040e+06 8.3886080e+06 1.6777216e+07
#  3.3554432e+07 1.1000000e+01 1.3000000e+01 1.5000000e+01 1.8000000e+01
#  2.0000000e+01 2.3000000e+01 2.5000000e+01 2.8000000e+01 3.0000000e+01
#  3.3000000e+01 3.5000000e+01 3.8000000e+01 4.0000000e+01 4.3000000e+01
#  4.5000000e+01 4.8000000e+01 5.0000000e+01 5.3000000e+01 5.5000000e+01
#  5.8000000e+01 6.0000000e+01]

# %%
length = int(len(data))
n_vals = data[0:int(len(data)/2)]
av_comp = data[int(len(data)/2):int(len(data))]

print(data)
print(n_vals)
print(av_comp)
# Out:
# [3.2000000e+01 6.4000000e+01 1.2800000e+02 2.5600000e+02 5.1200000e+02
#  1.0240000e+03 2.0480000e+03 4.0960000e+03 8.1920000e+03 1.6384000e+04
#  3.2768000e+04 6.5536000e+04 1.3107200e+05 2.6214400e+05 5.2428800e+05
#  1.0485760e+06 2.0971520e+06 4.1943040e+06 8.3886080e+06 1.6777216e+07
#  3.3554432e+07 1.1000000e+01 1.3000000e+01 1.5000000e+01 1.8000000e+01
#  2.0000000e+01 2.3000000e+01 2.5000000e+01 2.8000000e+01 3.0000000e+01
#  3.3000000e+01 3.5000000e+01 3.8000000e+01 4.0000000e+01 4.3000000e+01
#  4.5000000e+01 4.8000000e+01 5.0000000e+01 5.3000000e+01 5.5000000e+01
#  5.8000000e+01 6.0000000e+01]
# [3.2000000e+01 6.4000000e+01 1.2800000e+02 2.5600000e+02 5.1200000e+02
#  1.0240000e+03 2.0480000e+03 4.0960000e+03 8.1920000e+03 1.6384000e+04
#  3.2768000e+04 6.5536000e+04 1.3107200e+05 2.6214400e+05 5.2428800e+05
#  1.0485760e+06 2.0971520e+06 4.1943040e+06 8.3886080e+06 1.6777216e+07
#  3.3554432e+07]
# ...

# %%
from matplotlib import pyplot as plt

# Set the plot size
plt.figure(figsize=(15,7))

# Add grid with solid lines to graph
plt.grid(linestyle='dashed')

# Customize Plot
#plt.scale.LinearScale
plt.xlabel("$n$", fontsize='x-large')
plt.ylabel("Average Number of Comparisons", fontsize='x-large')
plt.title("Empirical investigation of binary search complexity", fontsize='xx-large')
plt.plot(n_vals, av_comp, "b-")
plt.show()
